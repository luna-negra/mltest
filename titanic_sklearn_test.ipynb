# %% [markdown]
# # Titanic Test

# %%
import pandas as pd

data = pd.read_csv("train.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(f"Columns: {data.columns}")
# Out:
# Columns: Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
print(f"Data Info: {data.info()}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# Data Info: None

# %%
print("Data Description")
data.describe()
# Out:
# Data Description
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### Some columns have Null value

# %%
null_check = data.isnull()
null_column_list = []

for column in data.columns:
   if any(data[column].isnull()):
       null_column_list.append(column)

print(null_column_list)
# Out:
# ['Age', 'Cabin', 'Embarked']

# %% [markdown]
# ### fillna: Cabin

# %%
data["Cabin"].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
data["Cabin"].isnull().value_counts()
# Out:
# Cabin
# True     687
# False    204
# Name: count, dtype: int64

# %%
data.fillna({"Cabin": "N"}, inplace=True)
data["Cabin"] = data["Cabin"].apply(lambda x: x[0])

# %%
data["Cabin"].value_counts()
# Out:
# Cabin
# N    687
# C     59
# B     47
# D     33
# E     32
# A     15
# F     13
# G      4
# T      1
# Name: count, dtype: int64

# %% [markdown]
# ### fillna(): Age

# %%
data["Age"].isnull().value_counts()
# Out:
# Age
# False    714
# True     177
# Name: count, dtype: int64

# %%
print(data["Age"].max())
print(data["Age"].mean())
print(data["Age"].min())
# Out:
# 80.0
# 29.69911764705882
# 0.42

# %%
mean_age = data["Age"].mean()
data.fillna({"Age": mean_age}, inplace=True)
data["Age"].isnull().value_counts()
# Out:
# Age
# False    891
# Name: count, dtype: int64

# %% [markdown]
# ### fillna(): Embarked

# %%
print(data["Embarked"].value_counts())
data["Embarked"].isnull().value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64
# Embarked
# False    889
# True       2
# Name: count, dtype: int64

# %%
data.fillna({"Embarked": "N"}, inplace=True)
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
data.isnull().value_counts()
# There is no N/A Value.
# Out:
# PassengerId  Survived  Pclass  Name   Sex    Age    SibSp  Parch  Ticket  Fare   Cabin  Embarked
# False        False     False   False  False  False  False  False  False   False  False  False       891
# Name: count, dtype: int64

# %%
# get rid of unneccesary columns: PassengerId, Name, Ticket, Cabin
new_data = data.drop(["Name", "Ticket", "Cabin"], axis=1)
new_data
# Out:
#      PassengerId  Survived  Pclass     Sex        Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.000000      1      0   7.2500
# 1              2         1       1  female  38.000000      1      0  71.2833
# 2              3         1       3  female  26.000000      0      0   7.9250
# 3              4         1       1  female  35.000000      1      0  53.1000
# 4              5         0       3    male  35.000000      0      0   8.0500
# ..           ...       ...     ...     ...        ...    ...    ...      ...
# 886          887         0       2    male  27.000000      0      0  13.0000
# 887          888         1       1  female  19.000000      0      0  30.0000
# 888          889         0       3  female  29.699118      1      2  23.4500
# 889          890         1       1    male  26.000000      0      0  30.0000
# 890          891         0       3    male  32.000000      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# ...

# %%
# Labeling for Model Learning
print(new_data.info())

# Label Encoding for "Sex" and "Embarked"
from sklearn.preprocessing import LabelEncoder

features = ["Sex", "Embarked"]
for f in features:
    encoder = LabelEncoder()
    encoder.fit(new_data[f])
    new_data[f] = encoder.transform(new_data[f])

new_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          891 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Fare         891 non-null    float64
#  8   Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 62.8+ KB
# None
#      PassengerId  Survived  Pclass  Sex        Age  SibSp  Parch     Fare  \
# 0              1         0       3    1  22.000000      1      0   7.2500
# 1              2         1       1    0  38.000000      1      0  71.2833
# 2              3         1       3    0  26.000000      0      0   7.9250
# ...

# %% [markdown]
# ### Analysis the Passenger

# %%
# split data in train.csv into test and train data set
# Data will be learned by DecisionTree, LogisticRegression and Random Forest.

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score


# split data set
X_data = new_data.drop("Survived", axis=1)
Y_data = new_data["Survived"]
X_train, X_test, Y_train, Y_test = train_test_split(X_data, Y_data, test_size=0.2, random_state=12)

# %%
dt_model = DecisionTreeClassifier()
lr_model = LogisticRegression()
rf_model = RandomForestClassifier()

model_list = [dt_model, lr_model, rf_model]
accuracy = []

for model in model_list:
    model.fit(X_train, Y_train)
    pred = model.predict(X_test)
    accuracy.append(accuracy_score(pred, Y_test))
# Out:
# /home/luna-negra/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
import numpy as np

result = {}
print(f"!! Normal Test Train Split")

for n in range(len(model_list)):
    result.update({model_list[n]: np.round(accuracy[n], 2)})

print(result)
# Out:
# !! Normal Test Train Split
# {DecisionTreeClassifier(): 0.7, LogisticRegression(): 0.77, RandomForestClassifier(): 0.75}

# %% [markdown]
# ### Each model has not high prediction score.
# - Possibility of Overfit
#
# => Use Cross Validation with KFold and StratifiedKFold

# %% [markdown]
# #### KFold

# %%
from sklearn.model_selection import KFold


kfold = KFold(n_splits=5)
max_score_model = ""
max_score = 0

for model in model_list:    
    for train_index, test_index in kfold.split(X_data):
        X_train, X_test = X_data.iloc[train_index], X_data.iloc[test_index]
        Y_train, Y_test = Y_data.iloc[train_index], Y_data.iloc[test_index]

        model.fit(X_train, Y_train)
        accuracy = np.round(accuracy_score(model.predict(X_test), Y_test), 2)
        if max_score < accuracy:
            max_score_model = str(model.__class__).split(".")[-1][:-2]
            max_score = accuracy

print(max_score_model)
print(max_score)
# Out:
# /home/luna-negra/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/luna-negra/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# #### StratifiedKFold with cross_val_score()

# %%
from sklearn.model_selection import cross_val_score


max_score_model = ""
max_score = 0

for model in model_list:
    scores = cross_val_score(model, X_data, Y_data, cv=5)

    for score in scores:
        if max_score < score:
            max_score_model = str(model.__class__).split(".")[-1][:-2]
            max_score = np.around(score, 2)

print(max_score_model)
print(max_score)
# Out:
# /home/luna-negra/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/luna-negra/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# ### Random Forest predict the test data with highest score.
# - do tuning on hyper parameters with GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

model = DecisionTreeClassifier()

# check parameters
print(model.get_params())
# Out:
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'random_state': None, 'splitter': 'best'}

# %%
params = {"max_depth": range(10), "max_leaf_nodes": range(10), "min_samples_leaf": range(10)}

# Define GridSearchCV
gscv = GridSearchCV(model, param_grid=params, scoring="accuracy", cv=5)
gscv.fit(X_train, Y_train)
# Out:
# /home/luna-negra/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 1760 fits failed out of a total of 5000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 500 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/luna-negra/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/luna-negra/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/home/luna-negra/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 666, in _validate_params
# ...

# %%
# Check the best Params
print(gscv.best_params_)
# Out:
# {'max_depth': 4, 'max_leaf_nodes': 7, 'min_samples_leaf': 3}

# %%
# Check the best score
print("---")
print(f"GridSearchCV Best Score: {np.round(gscv.best_score_, 2)}")
print("---")
# Out:
# ---
# GridSearchCV Best Score: 0.79
# ---

# %%
# Get the best Param and apply
tuned_model = gscv.best_estimator_
pred = tuned_model.predict(X_test)
print("---")
print(f"Model with Best HyperParameters Prediction: {np.around(accuracy_score(pred, Y_test), 2)}")
print("---")
# Out:
# ---
# Model with Best HyperParameters Prediction: 0.87
# ---
